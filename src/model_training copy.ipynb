# %% [markdown]
# # Quarterback Decision–Making Model

# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, brier_score_loss, mean_squared_error, classification_report, brier_score_loss
from sklearn.calibration import calibration_curve
from scipy.stats import pearsonr

import joblib


from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.neural_network import MLPClassifier, MLPRegressor

import os

# %% [markdown]
# ## Data Import and Processing

# %% [markdown]
# ### Data Imports

# %%
EXPERIMENT_NAME = "V_1"

raw_features = pd.read_csv("../data/play_features_2.csv")
outcomes = pd.read_csv("../data/play_outcomes_2.csv")

features = raw_features.rename(columns={"gameId": "game_id", "playId": "play_id", "frameId": "frame_id", "los": "line_of_scrimmage"})

# %% [markdown]
# ### Add Target Recievers

# %%
# Merge to get targeted_receiver_nflId
features = features.merge(outcomes[["game_id", "play_id", "targeted_receiver_nflId"]], on=["game_id", "play_id"], how="left")

# Get index of targeted receiver (players 6 to 10)
def get_receiver_index(row):
    for i in range(1, 6):
        if row.get(f"player_{i}_nflId") == row["targeted_receiver_nflId"]:
            return i - 1
    return -1

features["target_receiver_index"] = features.apply(get_receiver_index, axis=1)
features = features[features["target_receiver_index"] != -1].copy()

# %%
# Merge end_frame, filter to final frame
features = features.merge(outcomes[["game_id", "play_id", "end_frame"]], on=["game_id", "play_id"], how="left")
features.drop(columns=["end_frame"], inplace=True)

# %%
receiver_attrs = ['x', 'x_relative', 'y', 's', 'a', 'dis', 'o', 'dir', 'route']
targeted_features = []

for idx, row in features.iterrows():
    idx_target = int(row["target_receiver_index"])
    if 0 <= idx_target <= 4:
        f_row = [row.get(f"player_{idx_target + 1}_{attr}", 0.0) for attr in receiver_attrs]
    else:
        f_row = [0.0] * len(receiver_attrs)
    
    targeted_features.append(f_row)

targeted_df = pd.DataFrame(targeted_features, columns=[f"target_{attr}" for attr in receiver_attrs])
features = pd.concat([features.reset_index(drop=True), targeted_df], axis=1)

# %%
# One-hot encode each player's route and rename with prefix
for i in range(1, 6):
    route_col = f"player_{i}_route"
    dummies = pd.get_dummies(features[route_col], prefix=route_col)
    features = pd.concat([features, dummies], axis=1)
route_col = f"target_route"
dummies = pd.get_dummies(features[route_col], prefix=route_col)
features = pd.concat([features, dummies], axis=1)

# Optional: drop original route columns

# %%
# Define the suffix to drop
suffix_to_drop = '_route'

# Create a new DataFrame excluding columns ending with the suffix
features = features[[col for col in features.columns if not col.endswith(suffix_to_drop)]]

# %%
game_state_cats = [
    "offense_formation",
    "receiver_alignment",
    "dropback_type",
    "pff_pass_coverage",
    "pff_man_zone"
]

for cat in game_state_cats:
    dummies = pd.get_dummies(outcomes[cat], prefix=cat)
    outcomes = pd.concat([outcomes, dummies], axis=1)

outcomes.drop(game_state_cats, axis=1, inplace=True)

# %% [markdown]
# ### Data Processing

# %%
# Ensure numeric types
for col in features.select_dtypes(include=['object']).columns:
    features[col] = pd.to_numeric(features[col], errors='coerce')

for col in ["game_id", "play_id", "targeted_receiver_nflId", "start_frame", "end_frame",
            "down", "yards_to_go", "line_of_scrimmage", "yards_gained", "time_to_throw",
             "score_differential", "win_probability", "quarter", "seconds_to_half", 
             "play_clock_at_snap", "caused_pressure_count"]:
    outcomes[col] = pd.to_numeric(outcomes[col], errors='coerce')

# %%
# Filter valid pass results
outcomes = outcomes[outcomes["pass_result"].isin(["C", "I", "IN"])]

# %% [markdown]
# ### Add Target Recievers

# %%
features = features.drop(columns=[c for c in features.columns if c in outcomes.columns and c not in ['game_id', 'play_id']])
features = features.merge(outcomes, on=['game_id', 'play_id'], how='left')
features["frames_from_snap"] = features["frame_id"] - features["start_frame"]

# %%
# []
# df['col_obj'] = df['col_obj'].astype(int)

# Step 1: Convert 'object' type booleans to actual booleans (if needed)
# Example mapping — adapt to your data
bool_map = {
    'True': True, 'False': False,
    'true': True, 'false': False,
    'yes': True, 'no': False,
    '1': True, '0': False
}

for col in ["first_half", "play_action", "unblocked_pressure"]:
    if features[col].dtype == 'object':
        # Try to coerce to boolean using mapping or pandas conversion
        features[col] = features[col].map(bool_map).astype('bool', errors='ignore')

# Step 2: Convert all booleans to integers (0 or 1)
bool_cols = features.select_dtypes(include='bool').columns
features[bool_cols] = features[bool_cols].astype(int)

# Step 3 (optional): If you want to scale booleans, include them in scaler input
# Otherwise, you can exclude them and reattach later

# %%
def apply_horizontal_flip(df, flip_enabled=True):
    if not flip_enabled:
        return df.copy()

    df = df.copy()
    for i in range(23):
        df[f"player_{i}_y"] = 53.3 - df[f"player_{i}_y"]
        df[f"player_{i}_o"] = (180 - df[f"player_{i}_o"]) % 360
        df[f"player_{i}_dir"] = (180 - df[f"player_{i}_dir"]) % 360
    return df

def apply_gaussian_noise(df, features, std=0.5, noise_enabled=True):
    if not noise_enabled:
        return df.copy()

    df = df.copy()
    for feature in features:
        if feature in df.columns:
            df[feature] += np.random.normal(0, std, size=df.shape[0])
    return df

# %% [markdown]
# ### Augment Features

# %%
# def augment_features(df, 
#                      flip=True, 
#                      add_noise=True, 
#                      mult_noise=False,
#                      noise_std_add=0.3,
#                      noise_std_mult=0.05):
#     df_aug = df.copy()

#     # 1) Flip horizontally across y-axis
#     if flip:
#         for i in range(23):
#             df_aug[f"player_{i}_y"] = 53.3 - df_aug[f"player_{i}_y"]
#             df_aug[f"player_{i}_o"] = (180 - df_aug[f"player_{i}_o"]) % 360
#             df_aug[f"player_{i}_dir"] = (180 - df_aug[f"player_{i}_dir"]) % 360

#     # 2) Gaussian additive noise (good for positions)
#     if add_noise:
#         noise_features = [c for c in df_aug.columns if any(x in c for x in ["_x","_y","_s","_a","_dis"])]
#         for c in noise_features:
#             df_aug[c] += np.random.normal(0, noise_std_add, size=len(df_aug))

#     # 3) Multiplicative noise (optional, good for angles)
#     if mult_noise:
#         angle_features = [c for c in df_aug.columns if "_o" in c or "_dir" in c]
#         for c in angle_features:
#             df_aug[c] *= np.random.normal(1, noise_std_mult, size=len(df_aug))

#     return df_aug

# # Usage:
# augmented_df = augment_features(features, flip=True, add_noise=True, mult_noise=True)
# features = pd.concat([features, augmented_df], axis=0).reset_index(drop=True)

# %%
import torch
import numpy as np

def augment_tensor_features(tensor,
                            feature_names,
                            flip_prob=0.5,
                            noise_add_prob=0.5,
                            mult_noise_prob=0.5,
                            noise_std_add=0.3,
                            noise_std_mult=0.05,
                            flip_features=None,
                            rotate_features=None):
    """
    Apply dynamic augmentation to a feature tensor.
    
    Args:
        tensor (torch.Tensor): shape (batch_size, num_features)
        feature_names (list[str]): feature names matching tensor dim 1
        flip_prob (float): probability to apply y-flip
        noise_add_prob (float): probability to add Gaussian noise
        mult_noise_prob (float): probability to apply multiplicative noise
        noise_std_add (float): std dev for additive noise
        noise_std_mult (float): std dev for multiplicative noise
        flip_features (list[str]): substrings of features to y-flip (e.g., ['_y'])
        rotate_features (list[str]): substrings of angle features to rotate (e.g., ['_o', '_dir'])
    
    Returns:
        torch.Tensor: Augmented tensor
    """
    tensor_aug = tensor.clone()

    # Boolean masks for each type
    feature_names = np.array(feature_names)
    flip_mask = torch.tensor([any(k in name for k in flip_features or []) for name in feature_names], dtype=torch.bool)
    rotate_mask = torch.tensor([any(k in name for k in rotate_features or []) for name in feature_names], dtype=torch.bool)
    add_noise_mask = torch.tensor([any(k in name for k in ['_x','_y','_s','_a','_dis']) for name in feature_names], dtype=torch.bool)
    mult_noise_mask = torch.tensor([any(k in name for k in ['_o','_dir']) for name in feature_names], dtype=torch.bool)

    # Apply flipping (if chosen)
    if np.random.rand() < flip_prob:
        tensor_aug[:, flip_mask] = 53.3 - tensor_aug[:, flip_mask]
        if rotate_features:
            tensor_aug[:, rotate_mask] = (180 - tensor_aug[:, rotate_mask]) % 360

    # Additive Gaussian noise
    if np.random.rand() < noise_add_prob:
        noise = torch.randn_like(tensor_aug[:, add_noise_mask]) * noise_std_add
        tensor_aug[:, add_noise_mask] += noise

    # Multiplicative noise (for angles)
    if np.random.rand() < mult_noise_prob:
        mult_noise = torch.randn_like(tensor_aug[:, mult_noise_mask]) * noise_std_mult + 1
        tensor_aug[:, mult_noise_mask] *= mult_noise

    return tensor_aug

# %% [markdown]
# ### Drop Unnecessary Features

# %%
# Drop non-numeric, identifier, or irrelevant fields
cols_to_drop = [col for col in features.columns 
                if col.endswith("displayName_x") or col.endswith("nflId") 
                or col.endswith("_position") or col.endswith("displayName_y")
                or col in ["start_frame", "end_frame", "game_id", "play_id", "frame_id",
                           "yards_gained", "pass_result", "play_type", "targeted_receiver_nflId",
                           "player_22_nflId", "player_22_position", "player_22_o", "player_22_dir", 
                           "time_to_throw", "targeted_receiver", "player22_dir", "player22_position", 
                           "player22_displayName_y"]]

# %%
# Out:
# 0        1
# 1        1
# 2        1
# 3        1
# 4        1
#         ..
# 12116    1
# 12117    1
# 12118    1
# 12119    1
# 12120    1
# Name: pass_result, Length: 12121, dtype: int32

# %%
# Classification dataset
clf_df = features.dropna(subset=["pass_result"]).copy()
X_clf = clf_df.drop(columns=cols_to_drop)
y_clf = clf_df["pass_result"]
le = LabelEncoder()
y_clf_enc = le.fit_transform(y_clf)  # ["C", "I", "IN"] → [0, 1, 2]

# Regression dataset (only completions)
reg_df = features[features["pass_result"] == "C"].copy()
X_reg = reg_df.drop(columns=cols_to_drop)
y_reg = reg_df["yards_gained"]

# %%
cols_to_drop_2 = [col for col in features.columns 
                if col.endswith("displayName_x") 
                or col.endswith("_position") or col.endswith("displayName_y")
                or col in ["start_frame", "end_frame", 
                           "play_type", "targeted_receiver_nflId",
                           "player_22_nflId", "player_22_position", "player_22_o", "player_22_dir", 
                           "time_to_throw", "targeted_receiver", "player22_dir", "player22_position", 
                           "player22_displayName_y"]]

# %%
column_dtypes = X_clf.dtypes

# Filter for columns that are not float64
non_float64_columns = column_dtypes[(column_dtypes != np.float64) & (column_dtypes != bool)]
non_float64_columns
# Out:
# target_receiver_index                  int64
# player_1_route_CORNER                  int32
# player_1_route_CROSS                   int32
# player_1_route_FLAT                    int32
# player_1_route_GO                      int32
#                                        ...
# pff_pass_coverage_pff_pass_coverage    int32
# pff_man_zone_Man                       int32
# pff_man_zone_Other                     int32
# pff_man_zone_Zone                      int32
# pff_man_zone_pff_man_zone              int32
# Length: 121, dtype: object

# %%
summary_stats = X_reg.describe().T[["min","max"]]
summary_stats["range"] = summary_stats["max"] - summary_stats["min"]
print(summary_stats.tail(20))  # first 20 features

# Addative      
# Multiplicative
# Out:
#                                         min  max  range
# pff_pass_coverage_Cover-1               NaN  NaN    NaN
# pff_pass_coverage_Cover-1 Double        NaN  NaN    NaN
# pff_pass_coverage_Cover-2               NaN  NaN    NaN
# pff_pass_coverage_Cover-3               NaN  NaN    NaN
# pff_pass_coverage_Cover-3 Cloud Left    NaN  NaN    NaN
# pff_pass_coverage_Cover-3 Cloud Right   NaN  NaN    NaN
# pff_pass_coverage_Cover-3 Double Cloud  NaN  NaN    NaN
# pff_pass_coverage_Cover-3 Seam          NaN  NaN    NaN
# pff_pass_coverage_Cover-6 Right         NaN  NaN    NaN
# pff_pass_coverage_Goal Line             NaN  NaN    NaN
# pff_pass_coverage_Miscellaneous         NaN  NaN    NaN
# pff_pass_coverage_Prevent               NaN  NaN    NaN
# pff_pass_coverage_Quarters              NaN  NaN    NaN
# pff_pass_coverage_Red Zone              NaN  NaN    NaN
# pff_pass_coverage_pff_pass_coverage     NaN  NaN    NaN
# pff_man_zone_Man                        NaN  NaN    NaN
# pff_man_zone_Other                      NaN  NaN    NaN
# pff_man_zone_Zone                       NaN  NaN    NaN
# pff_man_zone_pff_man_zone               NaN  NaN    NaN
# frames_from_snap                        NaN  NaN    NaN

# %% [markdown]
# ### Train Test Split

# %%
# 5) Scale features
scaler_c = StandardScaler().fit(X_clf)

Xc_s = scaler_c.transform(X_clf)

Xr_s = scaler_c.transform(X_reg)

joblib.dump(scaler_c, "../models/scaler_c.pkl") #saved
print("Scaler saved!")


Xc_train, Xc_test, yc_train, yc_test = train_test_split(
    Xc_s, y_clf_enc, test_size=0.2, random_state=42, stratify=y_clf_enc
)
Xr_train, Xr_test, yr_train, yr_test = train_test_split(
    Xr_s, y_reg, test_size=0.2, random_state=42
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 6
#       2 scaler_c = StandardScaler().fit(X_clf)
#       4 Xc_s = scaler_c.transform(X_clf)
# ----> 6 Xr_s = scaler_c.transform(X_reg)
#       8 joblib.dump(scaler_c, "../models/scaler_c.pkl") #saved
#       9 print("Scaler saved!")
#
# File c:\Users\jesse\anaconda3\envs\nflenv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return_tuple = (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File c:\Users\jesse\anaconda3\envs\nflenv\lib\site-packages\sklearn\preprocessing\_data.py:1004, in StandardScaler.transform(self, X, copy)
#    1001 check_is_fitted(self)
#    1003 copy = copy if copy is not None else self.copy
# -> 1004 X = self._validate_data(
#    1005     X,
#    1006     reset=False,
#    1007     accept_sparse="csr",
#    1008     copy=copy,
#    1009     dtype=FLOAT_DTYPES,
#    1010     force_all_finite="allow-nan",
#    1011 )
#    1013 if sparse.issparse(X):
#    1014     if self.with_mean:
#
# File c:\Users\jesse\anaconda3\envs\nflenv\lib\site-packages\sklearn\base.py:604, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     602         out = X, y
#     603 elif not no_val_X and no_val_y:
# --> 604     out = check_array(X, input_name="X", **check_params)
#     605 elif no_val_X and not no_val_y:
#     606     out = _check_y(y, **check_params)
#
# File c:\Users\jesse\anaconda3\envs\nflenv\lib\site-packages\sklearn\utils\validation.py:969, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     967     n_samples = _num_samples(array)
#     968     if n_samples < ensure_min_samples:
# --> 969         raise ValueError(
#     970             "Found array with %d sample(s) (shape=%s) while a"
#     971             " minimum of %d is required%s."
#     972             % (n_samples, array.shape, ensure_min_samples, context)
#     973         )
#     975 if ensure_min_features > 0 and array.ndim == 2:
#     976     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 321)) while a minimum of 1 is required by StandardScaler.

# %%
# Out:
# Empty DataFrame
# Columns: [player_0_x, player_0_x_relative, player_0_y, player_0_s, player_0_a, player_0_dis, player_0_o, player_0_dir, player_1_x, player_1_x_relative, player_1_y, player_1_s, player_1_a, player_1_dis, player_1_o, player_1_dir, player_2_x, player_2_x_relative, player_2_y, player_2_s, player_2_a, player_2_dis, player_2_o, player_2_dir, player_3_x, player_3_x_relative, player_3_y, player_3_s, player_3_a, player_3_dis, player_3_o, player_3_dir, player_4_x, player_4_x_relative, player_4_y, player_4_s, player_4_a, player_4_dis, player_4_o, player_4_dir, player_5_x, player_5_x_relative, player_5_y, player_5_s, player_5_a, player_5_dis, player_5_o, player_5_dir, player_6_x, player_6_x_relative, player_6_y, player_6_s, player_6_a, player_6_dis, player_6_o, player_6_dir, player_7_x, player_7_x_relative, player_7_y, player_7_s, player_7_a, player_7_dis, player_7_o, player_7_dir, player_8_x, player_8_x_relative, player_8_y, player_8_s, player_8_a, player_8_dis, player_8_o, player_8_dir, player_9_x, player_9_x_relative, player_9_y, player_9_s, player_9_a, player_9_dis, player_9_o, player_9_dir, player_10_x, player_10_x_relative, player_10_y, player_10_s, player_10_a, player_10_dis, player_10_o, player_10_dir, player_11_x, player_11_x_relative, player_11_y, player_11_s, player_11_a, player_11_dis, player_11_o, player_11_dir, player_12_x, player_12_x_relative, player_12_y, player_12_s, ...]
# Index: []
#
# [0 rows x 321 columns]

# %%
#export features for the animation
import pandas as pd
import numpy as np

# 1️⃣ Create the dataframe with columns you want to export (keeps extra metadata)
export_features = features.drop(columns=cols_to_drop_2).copy()

# 2️⃣ Identify which columns in export_features were actually used for training
train_feature_cols = X_clf.columns.intersection(export_features.columns)

# 3️⃣ Scale ONLY the training columns using the scaler trained on X_clf
scaled_values = scaler_c.transform(export_features[train_feature_cols])

# Replace original training feature columns with their scaled versions
export_features.loc[:, train_feature_cols] = scaled_values

print("✅ export_features created with scaled training features & unscaled metadata columns")

# Optional: Save it for later use
# export_features.to_csv("../data/export_features.csv", index=False)
# print("✅ Saved to ../data/export_features.csv")
# Out:
# ✅ export_features created with scaled training features & unscaled metadata columns
# C:\Users\jesse\AppData\Local\Temp\ipykernel_28116\2290818748.py:15: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[ 1.33426411 -0.08859915  0.62283248 ... -0.80003079  0.62283248
#  -0.80003079]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   export_features.loc[:, train_feature_cols] = scaled_values

# %%
# reg_model(torch.tensor(Xc_s[0], dtype=torch.float32).unsqueeze(

# %%
# Convert to torch tensors
Xc_train_tensor = torch.tensor(Xc_train, dtype=torch.float32)
Xc_test_tensor  = torch.tensor(Xc_test, dtype=torch.float32)
yc_train_tensor = torch.tensor(yc_train, dtype=torch.long)
yc_test_tensor  = torch.tensor(yc_test, dtype=torch.long)

Xr_train_tensor = torch.tensor(Xr_train, dtype=torch.float32)
Xr_test_tensor  = torch.tensor(Xr_test, dtype=torch.float32)
yr_train_tensor = torch.tensor(yr_train.values, dtype=torch.float32).unsqueeze(1)
yr_test_tensor  = torch.tensor(yr_test.values, dtype=torch.float32).unsqueeze(1)

# %%
class FootballDataset(torch.utils.data.Dataset):
    def __init__(self, X, y, feature_names, augment=False, augment_params=None):
        self.X = torch.tensor(X, dtype=torch.float32)
        self.y = y  # or float32 for regression
        self.feature_names = feature_names
        self.augment = augment
        self.augment_params = augment_params or {}

    def __len__(self):
        return len(self.X)

    def __getitem__(self, idx):
        x = self.X[idx]
        y = self.y[idx]

        if self.augment:
            x = augment_tensor_features(
                x.unsqueeze(0),  # add batch dim
                self.feature_names,
                **self.augment_params
            ).squeeze(0)  # remove batch dim

        return x, y

# %%
flip_features = [col for col in X_clf.columns if col.endswith('_y')]
rotate_features = [col for col in X_clf.columns if col.endswith('_o') or col.endswith('_dir')]


augment_params = {
    "flip_prob": 0.5,
    "noise_add_prob": 0.5,
    "mult_noise_prob": 0.3,
    "noise_std_add": 0.2,
    "noise_std_mult": 0.03,
    "flip_features": flip_features,
    "rotate_features": rotate_features
}


Xc_train_dataset = FootballDataset(Xc_train_tensor, yc_train_tensor, X_clf.columns.tolist(), augment=True, augment_params=augment_params)
Xc_val_dataset = FootballDataset(Xc_test_tensor, yc_test_tensor, X_clf.columns.tolist(), augment=False)

Xr_train_dataset = FootballDataset(Xr_train_tensor, yr_train_tensor, X_clf.columns.tolist(), augment=True, augment_params=augment_params)
Xr_val_dataset = FootballDataset(Xr_test_tensor, yr_test_tensor, X_clf.columns.tolist(), augment=False)
# Out:
# C:\Users\jesse\AppData\Local\Temp\ipykernel_28116\2137398372.py:3: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.X = torch.tensor(X, dtype=torch.float32)

# %% [markdown]
# ## Model Architecture

# %%
class Net(nn.Module):
    def __init__(self, input_dim, output_dim):
        super(Net, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(input_dim, 230),
            nn.ReLU(),
            nn.BatchNorm1d(230),

            nn.Dropout(0.6),
            nn.Linear(230, 256),
            nn.ReLU(),
            nn.BatchNorm1d(256),

            nn.Dropout(0.6),
            nn.Linear(256, 128),
            nn.ReLU(),
            
            nn.Linear(128, output_dim)
        )

    def forward(self, x):
        return self.layers(x)

# %%
# Model 1 (classification)
clf_model = Net(Xc_train.shape[1], 3)
optimizer_clf = optim.Adam(clf_model.parameters(), lr=1e-3)
criterion_clf = nn.CrossEntropyLoss(label_smoothing=0.05)

# (Train loop + loss tracking and test evaluation)

## 7. 🚂 Train Regressor
# Model 2 (regression)
reg_model = Net(Xr_train.shape[1], 1)
optimizer_reg = optim.Adam(reg_model.parameters(), lr=1e-4, weight_decay=1e-5)
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4, weight_decay=1e-5)

criterion_reg = nn.MSELoss()
# criterion_reg = nn.SmoothL1Loss(beta=1.0) #fixme


# class LabelSmoothingLoss(nn.Module):
#     def __init__(self, classes, smoothing=0.1):
#         super(LabelSmoothingLoss, self).__init__()
#         self.confidence = 1.0 - smoothing
#         self.smoothing = smoothing
#         self.cls = classes
#         self.log_softmax = nn.LogSoftmax(dim=-1)

#     def forward(self, x, target):
#         log_probs = self.log_softmax(x)
#         with torch.no_grad():
#             true_dist = torch.zeros_like(log_probs)
#             true_dist.fill_(self.smoothing / (self.cls - 1))
#             true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence)
#         return torch.mean(torch.sum(-true_dist * log_probs, dim=-1))

# # Example use:
# criterion_clf = LabelSmoothingLoss(classes=3, smoothing=0.1)

# %% [markdown]
# ## Training

# %% [markdown]
# ### Classification Model Training

# %%
# train_losses, test_losses = [], []
# train_acc, test_acc = [], []


# for epoch in range(30):
#     clf_model.train()
#     optimizer_clf.zero_grad()
#     outputs = clf_model(Xc_train_tensor)
    
#     loss = criterion_clf(outputs, yc_train_tensor)
#     loss.backward()
#     optimizer_clf.step()
#     train_losses.append(loss.item())

#     # get accuracy
#     class_probs = torch.softmax(outputs, dim=1)
#     class_preds = torch.argmax(class_probs, dim=1)
#     total_correct = (class_preds == yc_train_tensor).sum().item()
#     total_class = yc_train_tensor.size(0)
#     train_acc.append(total_correct / total_class)

#     # Evaluate
#     clf_model.eval()
#     with torch.no_grad():
#         val_outputs = clf_model(Xc_test_tensor)
#         val_loss = criterion_clf(val_outputs, yc_test_tensor).item()
#         test_losses.append(val_loss)
#             # get accuracy
#         class_probs = torch.softmax(val_outputs, dim=1)
#         class_preds = torch.argmax(class_probs, dim=1)
#         total_correct = (class_preds == yc_test_tensor).sum().item()
#         total_class = yc_test_tensor.size(0)
#         test_acc.append(total_correct / total_class)


#     print(f"Epoch {epoch+1}: Train Loss = {loss.item():.4f}, Train Accuracy = {train_acc[-1]:.4f}, Test Loss = {val_loss:.4f}, Test Accuracy = {total_correct / total_class:.4f}")

# # Save model

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create DataLoaders
batch_size = 128  # try 256 or 512 later to see impact


train_loader = DataLoader(Xc_train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(Xc_val_dataset, batch_size=batch_size)

train_losses, test_losses = [], []
train_acc, test_acc = [], []
best_val_loss = 100000
patience = 15
count = 0

for epoch in range(100):
    clf_model.train()
    total_train_loss = 0
    correct_train = 0
    total_samples = 0

    for xb, yb in train_loader:
        optimizer_clf.zero_grad()
        outputs = clf_model(xb)
        loss = criterion_clf(outputs, yb)
        loss.backward()
        optimizer_clf.step()
        
        total_train_loss += loss.item() * xb.size(0)
        preds = torch.argmax(torch.softmax(outputs, dim=1), dim=1)
        correct_train += (preds == yb).sum().item()
        total_samples += yb.size(0)

    avg_train_loss = total_train_loss / total_samples
    avg_train_acc = correct_train / total_samples
    train_losses.append(avg_train_loss)
    train_acc.append(avg_train_acc)

    # Evaluation
    clf_model.eval()
    total_val_loss = 0
    correct_val = 0
    val_samples = 0

    with torch.no_grad():
        for xb, yb in test_loader:
            outputs = clf_model(xb)
            loss = criterion_clf(outputs, yb)
            total_val_loss += loss.item() * xb.size(0)
            preds = torch.argmax(torch.softmax(outputs, dim=1), dim=1)
            correct_val += (preds == yb).sum().item()
            val_samples += yb.size(0)

    avg_val_loss = total_val_loss / val_samples
    avg_val_acc = correct_val / val_samples
    test_losses.append(avg_val_loss)
    test_acc.append(avg_val_acc)
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
    else:
        count += 1
        if count > patience:
            print("early stopping")
            break

    print(f"Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f}, Train Accuracy = {avg_train_acc:.4f}, Test Loss = {avg_val_loss:.4f}, Test Accuracy = {avg_val_acc:.4f}")
# Out:
# Epoch 1: Train Loss = 0.8159, Train Accuracy = 0.6525, Test Loss = 0.7417, Test Accuracy = 0.6740
# Epoch 2: Train Loss = 0.7734, Train Accuracy = 0.6641, Test Loss = 0.7374, Test Accuracy = 0.6800
# Epoch 3: Train Loss = 0.7607, Train Accuracy = 0.6723, Test Loss = 0.7368, Test Accuracy = 0.6860
# Epoch 4: Train Loss = 0.7570, Train Accuracy = 0.6758, Test Loss = 0.7266, Test Accuracy = 0.6776
# Epoch 5: Train Loss = 0.7547, Train Accuracy = 0.6752, Test Loss = 0.7360, Test Accuracy = 0.6866
# Epoch 6: Train Loss = 0.7530, Train Accuracy = 0.6770, Test Loss = 0.7272, Test Accuracy = 0.6908
# Epoch 7: Train Loss = 0.7479, Train Accuracy = 0.6816, Test Loss = 0.7291, Test Accuracy = 0.6824
# Epoch 8: Train Loss = 0.7452, Train Accuracy = 0.6810, Test Loss = 0.7310, Test Accuracy = 0.6782
# Epoch 9: Train Loss = 0.7473, Train Accuracy = 0.6794, Test Loss = 0.7298, Test Accuracy = 0.6830
# Epoch 10: Train Loss = 0.7465, Train Accuracy = 0.6782, Test Loss = 0.7323, Test Accuracy = 0.6800
# Epoch 11: Train Loss = 0.7433, Train Accuracy = 0.6798, Test Loss = 0.7309, Test Accuracy = 0.6824
# Epoch 12: Train Loss = 0.7410, Train Accuracy = 0.6867, Test Loss = 0.7349, Test Accuracy = 0.6794
# Epoch 13: Train Loss = 0.7414, Train Accuracy = 0.6873, Test Loss = 0.7303, Test Accuracy = 0.6776
# Epoch 14: Train Loss = 0.7401, Train Accuracy = 0.6879, Test Loss = 0.7430, Test Accuracy = 0.6770
# Epoch 15: Train Loss = 0.7358, Train Accuracy = 0.6854, Test Loss = 0.7352, Test Accuracy = 0.6800
# Epoch 16: Train Loss = 0.7345, Train Accuracy = 0.6928, Test Loss = 0.7334, Test Accuracy = 0.6770
# Epoch 17: Train Loss = 0.7352, Train Accuracy = 0.6891, Test Loss = 0.7343, Test Accuracy = 0.6782
# Epoch 18: Train Loss = 0.7392, Train Accuracy = 0.6861, Test Loss = 0.7374, Test Accuracy = 0.6746
# Epoch 19: Train Loss = 0.7337, Train Accuracy = 0.6889, Test Loss = 0.7365, Test Accuracy = 0.6782
# early stopping

# %% [markdown]
# ### Regression Model Training

# %%
# reg_train_losses, reg_test_losses = [], []

# for epoch in range(100):
#     reg_model.train()
#     optimizer_reg.zero_grad()
#     preds = reg_model(Xr_train_tensor)
#     loss = criterion_reg(preds, yr_train_tensor)
#     loss.backward()
#     optimizer_reg.step()
#     reg_train_losses.append(loss.item())

#     # Evaluate
#     reg_model.eval()
#     with torch.no_grad():
#         val_preds = reg_model(Xr_test_tensor)
#         val_loss = criterion_reg(val_preds, yr_test_tensor).item()
#         reg_test_losses.append(val_loss)

#     print(f"Epoch {epoch+1}: Train Loss = {loss.item():.4f}, Test Loss = {val_loss:.4f}")

# # Save model

# %%
from torch.utils.data import TensorDataset, DataLoader

# Create DataLoaders
batch_size = 128  # try 256 or 512 later to see impact


train_loader = DataLoader(Xr_train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(Xr_val_dataset, batch_size=batch_size)

reg_train_losses, reg_test_losses = [], []

for epoch in range(300):
    reg_model.train()
    total_train_loss = 0
    correct_train = 0
    total_samples = 0

    for xb, yb in train_loader:
        optimizer_reg.zero_grad()
        outputs = reg_model(xb)
        loss = criterion_reg(outputs, yb)
        loss.backward()
        optimizer_reg.step()
        
        total_train_loss += loss.item() * xb.size(0)
        total_samples += xb.size(0)


    avg_train_loss = total_train_loss / total_samples
    reg_train_losses.append(avg_train_loss)

    # Evaluation
    reg_model.eval()
    total_val_loss = 0
    val_samples = 0

    with torch.no_grad():
        for xb, yb in test_loader:
            outputs = reg_model(xb)
            loss = criterion_reg(outputs, yb)
            total_val_loss += loss.item() * xb.size(0)
            val_samples += yb.size(0)

    avg_val_loss = total_val_loss / val_samples
    reg_test_losses.append(avg_val_loss)

    print(f"Epoch {epoch+1}: Train Loss = {avg_train_loss:.4f},  Test Loss = {avg_val_loss:.4f}")
# Out:
# Epoch 1: Train Loss = 218.8984,  Test Loss = 229.0321
# Epoch 2: Train Loss = 208.7791,  Test Loss = 213.4368
# Epoch 3: Train Loss = 192.9986,  Test Loss = 189.7831
# Epoch 4: Train Loss = 168.3236,  Test Loss = 152.2191
# Epoch 5: Train Loss = 139.5360,  Test Loss = 124.0227
# Epoch 6: Train Loss = 116.4204,  Test Loss = 101.3778
# Epoch 7: Train Loss = 100.6358,  Test Loss = 86.5805
# Epoch 8: Train Loss = 94.3685,  Test Loss = 77.6734
# Epoch 9: Train Loss = 90.1628,  Test Loss = 73.3571
# Epoch 10: Train Loss = 86.8271,  Test Loss = 67.0949
# Epoch 11: Train Loss = 86.7864,  Test Loss = 62.7763
# Epoch 12: Train Loss = 85.5867,  Test Loss = 62.1260
# Epoch 13: Train Loss = 86.4325,  Test Loss = 58.9182
# Epoch 14: Train Loss = 88.1439,  Test Loss = 58.1977
# Epoch 15: Train Loss = 86.5867,  Test Loss = 59.3967
# Epoch 16: Train Loss = 82.8152,  Test Loss = 57.2169
# Epoch 17: Train Loss = 81.6344,  Test Loss = 56.8523
# Epoch 18: Train Loss = 81.3141,  Test Loss = 56.7765
# Epoch 19: Train Loss = 81.9272,  Test Loss = 54.9776
# Epoch 20: Train Loss = 82.6017,  Test Loss = 55.2300
# Epoch 21: Train Loss = 83.0956,  Test Loss = 55.2098
# Epoch 22: Train Loss = 82.4219,  Test Loss = 54.4573
# Epoch 23: Train Loss = 79.0541,  Test Loss = 53.8636
# Epoch 24: Train Loss = 82.3184,  Test Loss = 53.9832
# Epoch 25: Train Loss = 82.3910,  Test Loss = 58.6707
# Epoch 26: Train Loss = 80.0378,  Test Loss = 53.8553
# Epoch 27: Train Loss = 78.7682,  Test Loss = 55.0188
# Epoch 28: Train Loss = 79.4009,  Test Loss = 53.6298
# Epoch 29: Train Loss = 82.5301,  Test Loss = 52.9320
# Epoch 30: Train Loss = 80.1877,  Test Loss = 52.4543
# Epoch 31: Train Loss = 81.5550,  Test Loss = 53.1459
# Epoch 32: Train Loss = 80.4083,  Test Loss = 52.0355
# Epoch 33: Train Loss = 80.3812,  Test Loss = 54.2894
# Epoch 34: Train Loss = 79.3403,  Test Loss = 51.5773
# Epoch 35: Train Loss = 78.4698,  Test Loss = 52.5202
# Epoch 36: Train Loss = 81.3478,  Test Loss = 50.9039
# Epoch 37: Train Loss = 76.9573,  Test Loss = 53.8719
# Epoch 38: Train Loss = 79.8731,  Test Loss = 53.4097
# Epoch 39: Train Loss = 75.9634,  Test Loss = 52.8133
# Epoch 40: Train Loss = 79.5263,  Test Loss = 51.8831
# Epoch 41: Train Loss = 73.5300,  Test Loss = 51.9444
# Epoch 42: Train Loss = 76.2508,  Test Loss = 54.2243
# Epoch 43: Train Loss = 75.7559,  Test Loss = 52.4669
# Epoch 44: Train Loss = 76.3396,  Test Loss = 50.3020
# Epoch 45: Train Loss = 76.4302,  Test Loss = 50.0479
# Epoch 46: Train Loss = 76.0047,  Test Loss = 51.4442
# Epoch 47: Train Loss = 75.0485,  Test Loss = 55.9335
# Epoch 48: Train Loss = 76.4026,  Test Loss = 50.5899
# Epoch 49: Train Loss = 77.3269,  Test Loss = 50.6854
# Epoch 50: Train Loss = 72.5130,  Test Loss = 50.6236
# Epoch 51: Train Loss = 75.3114,  Test Loss = 49.5967
# Epoch 52: Train Loss = 74.8609,  Test Loss = 49.7532
# Epoch 53: Train Loss = 74.6350,  Test Loss = 50.3448
# Epoch 54: Train Loss = 75.6412,  Test Loss = 49.5993
# Epoch 55: Train Loss = 73.0739,  Test Loss = 49.6929
# Epoch 56: Train Loss = 71.7554,  Test Loss = 50.1791
# Epoch 57: Train Loss = 74.7660,  Test Loss = 49.8253
# Epoch 58: Train Loss = 75.1348,  Test Loss = 50.0044
# Epoch 59: Train Loss = 74.7830,  Test Loss = 53.9409
# Epoch 60: Train Loss = 77.4496,  Test Loss = 49.1297
# Epoch 61: Train Loss = 73.2276,  Test Loss = 50.7408
# Epoch 62: Train Loss = 78.2168,  Test Loss = 50.4766
# Epoch 63: Train Loss = 73.2608,  Test Loss = 49.7880
# Epoch 64: Train Loss = 69.9797,  Test Loss = 49.3251
# Epoch 65: Train Loss = 74.2609,  Test Loss = 49.1999
# Epoch 66: Train Loss = 70.7878,  Test Loss = 48.9237
# Epoch 67: Train Loss = 73.4176,  Test Loss = 49.1724
# Epoch 68: Train Loss = 71.1033,  Test Loss = 48.8573
# Epoch 69: Train Loss = 71.7492,  Test Loss = 49.2296
# Epoch 70: Train Loss = 70.8296,  Test Loss = 49.0082
# Epoch 71: Train Loss = 70.1807,  Test Loss = 48.7915
# Epoch 72: Train Loss = 72.8387,  Test Loss = 48.7828
# Epoch 73: Train Loss = 72.7275,  Test Loss = 49.0464
# Epoch 74: Train Loss = 72.6903,  Test Loss = 50.3137
# Epoch 75: Train Loss = 72.1520,  Test Loss = 49.2513
# Epoch 76: Train Loss = 71.7124,  Test Loss = 48.8712
# Epoch 77: Train Loss = 71.9060,  Test Loss = 49.3444
# Epoch 78: Train Loss = 72.6987,  Test Loss = 48.0962
# Epoch 79: Train Loss = 73.3648,  Test Loss = 48.0797
# Epoch 80: Train Loss = 70.4187,  Test Loss = 49.3648
# Epoch 81: Train Loss = 72.7768,  Test Loss = 48.5014
# Epoch 82: Train Loss = 69.4456,  Test Loss = 49.1761
# Epoch 83: Train Loss = 70.2697,  Test Loss = 48.6147
# Epoch 84: Train Loss = 69.8926,  Test Loss = 49.4037
# Epoch 85: Train Loss = 70.1429,  Test Loss = 48.0535
# Epoch 86: Train Loss = 71.6047,  Test Loss = 47.7614
# Epoch 87: Train Loss = 73.7439,  Test Loss = 48.7323
# Epoch 88: Train Loss = 69.8206,  Test Loss = 47.6795
# Epoch 89: Train Loss = 68.5447,  Test Loss = 47.7993
# Epoch 90: Train Loss = 70.8847,  Test Loss = 48.0336
# Epoch 91: Train Loss = 71.4112,  Test Loss = 47.9864
# Epoch 92: Train Loss = 71.0909,  Test Loss = 49.6536
# Epoch 93: Train Loss = 68.2391,  Test Loss = 48.0799
# Epoch 94: Train Loss = 67.2819,  Test Loss = 48.0269
# Epoch 95: Train Loss = 70.9041,  Test Loss = 48.1431
# Epoch 96: Train Loss = 71.1562,  Test Loss = 49.3444
# Epoch 97: Train Loss = 70.8360,  Test Loss = 47.8885
# Epoch 98: Train Loss = 69.2111,  Test Loss = 47.8213
# Epoch 99: Train Loss = 70.6836,  Test Loss = 47.9266
# Epoch 100: Train Loss = 69.8043,  Test Loss = 47.8675
# Epoch 101: Train Loss = 68.1797,  Test Loss = 47.6419
# Epoch 102: Train Loss = 71.3630,  Test Loss = 47.7777
# Epoch 103: Train Loss = 70.9251,  Test Loss = 48.0070
# Epoch 104: Train Loss = 72.0706,  Test Loss = 48.2490
# Epoch 105: Train Loss = 71.1474,  Test Loss = 48.0941
# Epoch 106: Train Loss = 72.2802,  Test Loss = 48.3829
# Epoch 107: Train Loss = 69.5342,  Test Loss = 48.3829
# Epoch 108: Train Loss = 68.9268,  Test Loss = 48.3431
# Epoch 109: Train Loss = 69.5471,  Test Loss = 47.7193
# Epoch 110: Train Loss = 70.5325,  Test Loss = 47.7459
# Epoch 111: Train Loss = 66.9830,  Test Loss = 47.6279
# Epoch 112: Train Loss = 69.4782,  Test Loss = 47.7862
# Epoch 113: Train Loss = 69.9341,  Test Loss = 49.3120
# Epoch 114: Train Loss = 69.7655,  Test Loss = 48.3452
# Epoch 115: Train Loss = 68.9665,  Test Loss = 47.9142
# Epoch 116: Train Loss = 67.6463,  Test Loss = 47.7695
# Epoch 117: Train Loss = 66.3065,  Test Loss = 47.7500
# Epoch 118: Train Loss = 67.0862,  Test Loss = 47.6472
# Epoch 119: Train Loss = 68.5427,  Test Loss = 47.8531
# Epoch 120: Train Loss = 69.3430,  Test Loss = 48.1387
# Epoch 121: Train Loss = 69.0205,  Test Loss = 48.2716
# Epoch 122: Train Loss = 69.9998,  Test Loss = 48.0291
# Epoch 123: Train Loss = 68.0796,  Test Loss = 48.0257
# Epoch 124: Train Loss = 70.1800,  Test Loss = 48.1697
# Epoch 125: Train Loss = 65.7117,  Test Loss = 47.8284
# Epoch 126: Train Loss = 68.5947,  Test Loss = 48.7332
# Epoch 127: Train Loss = 68.6791,  Test Loss = 47.7667
# Epoch 128: Train Loss = 69.0420,  Test Loss = 47.8378
# Epoch 129: Train Loss = 68.2272,  Test Loss = 47.7366
# Epoch 130: Train Loss = 66.5308,  Test Loss = 47.5123
# Epoch 131: Train Loss = 67.0976,  Test Loss = 48.0121
# Epoch 132: Train Loss = 69.0622,  Test Loss = 48.3435
# Epoch 133: Train Loss = 67.1107,  Test Loss = 47.9505
# Epoch 134: Train Loss = 71.8343,  Test Loss = 47.7763
# Epoch 135: Train Loss = 68.5699,  Test Loss = 47.4904
# Epoch 136: Train Loss = 71.3051,  Test Loss = 47.4677
# Epoch 137: Train Loss = 67.7990,  Test Loss = 47.3845
# Epoch 138: Train Loss = 68.7165,  Test Loss = 47.5185
# Epoch 139: Train Loss = 69.4656,  Test Loss = 47.8493
# Epoch 140: Train Loss = 69.3491,  Test Loss = 48.0282
# Epoch 141: Train Loss = 66.6406,  Test Loss = 47.5337
# Epoch 142: Train Loss = 67.6815,  Test Loss = 47.5198
# Epoch 143: Train Loss = 70.1323,  Test Loss = 48.3213
# Epoch 144: Train Loss = 69.3667,  Test Loss = 47.3158
# Epoch 145: Train Loss = 68.5270,  Test Loss = 47.9431
# Epoch 146: Train Loss = 68.3841,  Test Loss = 47.8292
# Epoch 147: Train Loss = 68.6742,  Test Loss = 47.6297
# Epoch 148: Train Loss = 68.0261,  Test Loss = 47.4604
# Epoch 149: Train Loss = 70.7265,  Test Loss = 47.6309
# Epoch 150: Train Loss = 70.0208,  Test Loss = 47.4835
# Epoch 151: Train Loss = 72.5328,  Test Loss = 48.1075
# Epoch 152: Train Loss = 71.9172,  Test Loss = 48.5208
# Epoch 153: Train Loss = 72.4214,  Test Loss = 48.3942
# Epoch 154: Train Loss = 70.6671,  Test Loss = 47.8210
# Epoch 155: Train Loss = 71.0930,  Test Loss = 48.1118
# Epoch 156: Train Loss = 71.5368,  Test Loss = 48.5402
# Epoch 157: Train Loss = 68.8623,  Test Loss = 47.3924
# Epoch 158: Train Loss = 72.8351,  Test Loss = 47.1672
# Epoch 159: Train Loss = 70.2200,  Test Loss = 47.4267
# Epoch 160: Train Loss = 70.7758,  Test Loss = 47.2619
# Epoch 161: Train Loss = 71.7354,  Test Loss = 47.1657
# Epoch 162: Train Loss = 67.8454,  Test Loss = 47.0052
# Epoch 163: Train Loss = 69.4885,  Test Loss = 46.9055
# Epoch 164: Train Loss = 71.0549,  Test Loss = 48.1100
# Epoch 165: Train Loss = 71.9969,  Test Loss = 47.3738
# Epoch 166: Train Loss = 72.1246,  Test Loss = 47.5497
# Epoch 167: Train Loss = 73.3555,  Test Loss = 47.3362
# Epoch 168: Train Loss = 69.8598,  Test Loss = 46.9571
# Epoch 169: Train Loss = 65.9165,  Test Loss = 47.5864
# Epoch 170: Train Loss = 67.6898,  Test Loss = 47.1305
# Epoch 171: Train Loss = 68.8566,  Test Loss = 48.8027
# Epoch 172: Train Loss = 69.6783,  Test Loss = 47.3706
# Epoch 173: Train Loss = 65.0551,  Test Loss = 46.7964
# Epoch 174: Train Loss = 67.2821,  Test Loss = 47.4472
# Epoch 175: Train Loss = 68.2614,  Test Loss = 46.8213
# Epoch 176: Train Loss = 65.4979,  Test Loss = 47.0369
# Epoch 177: Train Loss = 69.4589,  Test Loss = 48.9455
# Epoch 178: Train Loss = 64.6042,  Test Loss = 46.6318
# Epoch 179: Train Loss = 68.9295,  Test Loss = 46.7550
# Epoch 180: Train Loss = 70.1140,  Test Loss = 47.8619
# Epoch 181: Train Loss = 64.5283,  Test Loss = 47.7422
# Epoch 182: Train Loss = 67.7957,  Test Loss = 47.6447
# Epoch 183: Train Loss = 65.8049,  Test Loss = 47.2768
# Epoch 184: Train Loss = 67.7835,  Test Loss = 47.1904
# Epoch 185: Train Loss = 67.5786,  Test Loss = 47.3455
# Epoch 186: Train Loss = 68.5295,  Test Loss = 47.6008
# Epoch 187: Train Loss = 64.4273,  Test Loss = 47.9961
# Epoch 188: Train Loss = 69.6947,  Test Loss = 47.3310
# Epoch 189: Train Loss = 66.4338,  Test Loss = 47.3964
# Epoch 190: Train Loss = 68.5630,  Test Loss = 52.0693
# Epoch 191: Train Loss = 66.5990,  Test Loss = 48.3653
# Epoch 192: Train Loss = 68.1583,  Test Loss = 47.0556
# Epoch 193: Train Loss = 64.2364,  Test Loss = 47.3084
# Epoch 194: Train Loss = 62.7807,  Test Loss = 47.4840
# Epoch 195: Train Loss = 65.1423,  Test Loss = 47.3433
# Epoch 196: Train Loss = 62.4887,  Test Loss = 47.2167
# Epoch 197: Train Loss = 65.1378,  Test Loss = 47.0972
# Epoch 198: Train Loss = 62.6339,  Test Loss = 47.1441
# Epoch 199: Train Loss = 62.2064,  Test Loss = 48.1435
# Epoch 200: Train Loss = 63.2031,  Test Loss = 47.2807
# Epoch 201: Train Loss = 61.1463,  Test Loss = 46.9749
# Epoch 202: Train Loss = 62.4647,  Test Loss = 47.3768
# Epoch 203: Train Loss = 62.1162,  Test Loss = 47.1350
# Epoch 204: Train Loss = 66.2656,  Test Loss = 47.3925
# Epoch 205: Train Loss = 64.8684,  Test Loss = 47.4561
# Epoch 206: Train Loss = 64.4912,  Test Loss = 49.4619
# Epoch 207: Train Loss = 64.2244,  Test Loss = 47.8861
# Epoch 208: Train Loss = 62.5786,  Test Loss = 47.4876
# Epoch 209: Train Loss = 66.3941,  Test Loss = 47.9754
# Epoch 210: Train Loss = 62.1715,  Test Loss = 49.0914
# Epoch 211: Train Loss = 63.6643,  Test Loss = 46.7166
# Epoch 212: Train Loss = 67.8033,  Test Loss = 52.2750
# Epoch 213: Train Loss = 64.9985,  Test Loss = 48.9715
# Epoch 214: Train Loss = 61.0899,  Test Loss = 49.2173
# Epoch 215: Train Loss = 60.7451,  Test Loss = 47.2495
# Epoch 216: Train Loss = 64.0606,  Test Loss = 47.2492
# Epoch 217: Train Loss = 66.6031,  Test Loss = 47.1095
# Epoch 218: Train Loss = 59.4682,  Test Loss = 46.9049
# Epoch 219: Train Loss = 64.4218,  Test Loss = 48.3223
# Epoch 220: Train Loss = 65.4054,  Test Loss = 47.0972
# Epoch 221: Train Loss = 65.0277,  Test Loss = 47.3490
# Epoch 222: Train Loss = 63.0535,  Test Loss = 46.8808
# Epoch 223: Train Loss = 63.5605,  Test Loss = 47.0155
# Epoch 224: Train Loss = 63.4495,  Test Loss = 49.0656
# Epoch 225: Train Loss = 64.0015,  Test Loss = 46.8893
# Epoch 226: Train Loss = 59.8991,  Test Loss = 47.9843
# Epoch 227: Train Loss = 60.6509,  Test Loss = 46.6734
# Epoch 228: Train Loss = 62.0352,  Test Loss = 46.3424
# Epoch 229: Train Loss = 61.0966,  Test Loss = 47.9280
# Epoch 230: Train Loss = 64.0079,  Test Loss = 46.7317
# Epoch 231: Train Loss = 60.2905,  Test Loss = 47.8219
# Epoch 232: Train Loss = 62.6163,  Test Loss = 47.0649
# Epoch 233: Train Loss = 63.0751,  Test Loss = 47.1872
# Epoch 234: Train Loss = 61.3572,  Test Loss = 47.9797
# Epoch 235: Train Loss = 59.6252,  Test Loss = 47.7492
# Epoch 236: Train Loss = 62.4299,  Test Loss = 46.9236
# Epoch 237: Train Loss = 61.7220,  Test Loss = 47.2671
# Epoch 238: Train Loss = 58.9312,  Test Loss = 48.4799
# Epoch 239: Train Loss = 61.5938,  Test Loss = 49.2620
# Epoch 240: Train Loss = 62.0126,  Test Loss = 48.3897
# Epoch 241: Train Loss = 61.4000,  Test Loss = 47.5310
# Epoch 242: Train Loss = 59.4053,  Test Loss = 47.9807
# Epoch 243: Train Loss = 58.9651,  Test Loss = 47.4273
# Epoch 244: Train Loss = 59.9205,  Test Loss = 49.0731
# Epoch 245: Train Loss = 60.5595,  Test Loss = 49.1931
# Epoch 246: Train Loss = 59.8089,  Test Loss = 47.2955
# Epoch 247: Train Loss = 58.4747,  Test Loss = 47.8971
# Epoch 248: Train Loss = 62.0240,  Test Loss = 47.1201
# Epoch 249: Train Loss = 60.5597,  Test Loss = 47.5860
# Epoch 250: Train Loss = 63.8544,  Test Loss = 48.0896
# Epoch 251: Train Loss = 61.9946,  Test Loss = 47.8823
# Epoch 252: Train Loss = 62.3021,  Test Loss = 49.5349
# Epoch 253: Train Loss = 60.6410,  Test Loss = 47.8379
# Epoch 254: Train Loss = 59.2659,  Test Loss = 47.5870
# Epoch 255: Train Loss = 61.0545,  Test Loss = 47.4797
# Epoch 256: Train Loss = 60.3794,  Test Loss = 50.9167
# Epoch 257: Train Loss = 63.4863,  Test Loss = 48.7023
# Epoch 258: Train Loss = 59.8440,  Test Loss = 47.9593
# Epoch 259: Train Loss = 60.5806,  Test Loss = 48.0010
# Epoch 260: Train Loss = 56.1677,  Test Loss = 48.2721
# Epoch 261: Train Loss = 60.4016,  Test Loss = 48.3670
# Epoch 262: Train Loss = 60.8111,  Test Loss = 48.4601
# Epoch 263: Train Loss = 60.6031,  Test Loss = 49.3004
# Epoch 264: Train Loss = 61.1856,  Test Loss = 48.0888
# Epoch 265: Train Loss = 61.5528,  Test Loss = 48.5227
# Epoch 266: Train Loss = 59.9278,  Test Loss = 47.5494
# Epoch 267: Train Loss = 61.2892,  Test Loss = 47.4845
# Epoch 268: Train Loss = 61.0765,  Test Loss = 47.0398
# Epoch 269: Train Loss = 62.2068,  Test Loss = 48.4661
# Epoch 270: Train Loss = 63.5166,  Test Loss = 47.8744
# Epoch 271: Train Loss = 61.1360,  Test Loss = 47.5233
# Epoch 272: Train Loss = 63.2274,  Test Loss = 48.5039
# Epoch 273: Train Loss = 64.3086,  Test Loss = 48.7314
# Epoch 274: Train Loss = 59.5401,  Test Loss = 49.1285
# Epoch 275: Train Loss = 61.4885,  Test Loss = 47.8503
# Epoch 276: Train Loss = 63.4940,  Test Loss = 47.8975
# Epoch 277: Train Loss = 65.8583,  Test Loss = 47.4312
# Epoch 278: Train Loss = 65.9109,  Test Loss = 48.9209
# Epoch 279: Train Loss = 65.5488,  Test Loss = 48.0039
# Epoch 280: Train Loss = 68.8108,  Test Loss = 47.9469
# Epoch 281: Train Loss = 66.1165,  Test Loss = 47.5156
# Epoch 282: Train Loss = 61.9791,  Test Loss = 52.3091
# Epoch 283: Train Loss = 65.6078,  Test Loss = 49.0318
# Epoch 284: Train Loss = 64.8666,  Test Loss = 49.0581
# Epoch 285: Train Loss = 64.6064,  Test Loss = 48.7740
# Epoch 286: Train Loss = 65.0436,  Test Loss = 48.1141
# Epoch 287: Train Loss = 64.4943,  Test Loss = 48.4928
# Epoch 288: Train Loss = 64.6154,  Test Loss = 47.8953
# Epoch 289: Train Loss = 62.1153,  Test Loss = 47.9330
# Epoch 290: Train Loss = 66.9304,  Test Loss = 49.2538
# Epoch 291: Train Loss = 62.5187,  Test Loss = 48.6028
# Epoch 292: Train Loss = 64.1666,  Test Loss = 50.3572
# Epoch 293: Train Loss = 65.1688,  Test Loss = 48.8895
# Epoch 294: Train Loss = 64.5022,  Test Loss = 48.3812
# Epoch 295: Train Loss = 66.7444,  Test Loss = 49.5412
# Epoch 296: Train Loss = 62.2267,  Test Loss = 47.7891
# Epoch 297: Train Loss = 64.8982,  Test Loss = 48.5608
# Epoch 298: Train Loss = 66.0941,  Test Loss = 48.5106
# Epoch 299: Train Loss = 62.0802,  Test Loss = 48.6023
# Epoch 300: Train Loss = 63.1614,  Test Loss = 48.4641

# %%
# torch.save(clf_model.state_dict(), "../models/throw_classifier_v_aug.pt")

# torch.save(reg_model.state_dict(), "../models/throw_regressor_v_aug_best.pt")

# %%
# Load the classifier model weights
# clf_model.load_state_dict(torch.load("../models/throw_classifier_best.pt"))

# Load the regression model weights
# reg_model.load_state_dict(torch.load("../models/throw_regressor_v_aug_best.pt"))

# %% [markdown]
# ## Plots

# %% [markdown]
# ### Training Loss Plots

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(train_losses, label="Train Loss")
plt.plot(test_losses, label="Test Loss")
plt.title("Classification Loss")
plt.xlabel("Epoch")
plt.ylabel("CrossEntropy Loss")
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(reg_train_losses, label="Train Loss")
plt.plot(reg_test_losses, label="Test Loss")
plt.title("Regression Loss")
plt.xlabel("Epoch")
plt.ylabel("MSE Loss")
plt.legend()

plt.tight_layout()
plt.savefig("../outputs/images/training_loss_aug.png")
plt.show()

# %%
plt.plot(train_acc, label="Train Accuracy")
plt.plot(test_acc, label="Test Accuracy")
plt.title("Classification Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.savefig("../outputs/images/training_accuracy_aug.png")

plt.show()

# %% [markdown]
# ### Classification Prediction and Calibration

# %%
from sklearn.metrics import brier_score_loss
import numpy as np

def compute_ece(y_true, y_prob, n_bins=10):
    """Compute Expected Calibration Error (ECE) for binary probs"""
    bins = np.linspace(0, 1, n_bins + 1)
    bin_ids = np.digitize(y_prob, bins) - 1

    ece = 0.0
    for b in range(n_bins):
        mask = bin_ids == b
        if mask.sum() > 0:
            avg_conf = y_prob[mask].mean()
            avg_acc = y_true[mask].mean()
            ece += (mask.sum() / len(y_prob)) * abs(avg_acc - avg_conf)
    return ece

# === Model predictions (already have this part) ===
clf_model.eval()
with torch.no_grad():
    train_probs = torch.softmax(clf_model(Xc_train_tensor), dim=1).numpy()
    test_probs  = torch.softmax(clf_model(Xc_test_tensor), dim=1).numpy()

train_true_complete = (yc_train == 0).astype(int)
test_true_complete  = (yc_test == 0).astype(int)

train_pred_complete = train_probs[:, 0]  # prob of "Complete"
test_pred_complete  = test_probs[:, 0]

# === Compute metrics ===
brier_train = brier_score_loss(train_true_complete, train_pred_complete)
ece_train   = compute_ece(train_true_complete, train_pred_complete, n_bins=10)

brier_test  = brier_score_loss(test_true_complete, test_pred_complete)
ece_test    = compute_ece(test_true_complete, test_pred_complete, n_bins=10)

# === Calibration curves ===
from sklearn.calibration import calibration_curve
frac_pos_train, mean_pred_train = calibration_curve(train_true_complete, train_pred_complete, n_bins=10, strategy='quantile')
frac_pos_test, mean_pred_test   = calibration_curve(test_true_complete, test_pred_complete, n_bins=10, strategy='quantile')

# === Plot ===
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(mean_pred_train, frac_pos_train, "o-", label="Train")
plt.plot([0, 1], [0, 1], "k--", label="Perfect")
plt.title(f"Train Calibration\nBrier={brier_train:.4f}, ECE={ece_train:.4f}")
plt.xlabel("Mean Predicted Prob")
plt.ylabel("Fraction of Positives")
plt.grid(True)
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(mean_pred_test, frac_pos_test, "o-", label="Test")
plt.plot([0, 1], [0, 1], "k--", label="Perfect")
plt.title(f"Test Calibration\nBrier={brier_test:.4f}, ECE={ece_test:.4f}")
plt.xlabel("Mean Predicted Prob")
plt.ylabel("Fraction of Positives")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.savefig("../outputs/images/calibration_plots_aug.png")

plt.show()

# %%
test_true_complete.mean(), test_pred_complete.mean()
# Out:
# (0.6716507177033493, 0.6766331)

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)

plt.hist(train_pred_complete)

plt.xlabel("Predicted Completion Percentage")
plt.ylabel("Frequency")
plt.title("Distribution of Train Classification Outputs")

plt.subplot(1, 2, 2)

plt.hist(test_pred_complete)

plt.xlabel("Predicted Completion Percentage")
plt.ylabel("Frequency")
plt.title("Distribution of Test Classification Outputs")
plt.savefig("../outputs/images/competion_percentage_histogram_aug.png")

plt.show()

# %%
train_true_interception = (yc_train == 2).astype(int)
train_prob_interception = train_probs[:, 2]

test_true_interception = (yc_test == 2).astype(int)
test_prob_interception = test_probs[:, 2]

frac_pos, mean_pred = calibration_curve(train_true_interception, train_prob_interception, n_bins=10, strategy='quantile')
brier = brier_score_loss(train_true_interception, train_prob_interception)
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(mean_pred, frac_pos, 'o-', label="Model")
plt.plot([0, 1], [0, 1], 'k--', label="Perfect")
plt.title(f"Calibration Curve for 'Interception' Training\nBrier Score: {brier:.4f}")
plt.xlabel("Mean Predicted Prob")
plt.ylabel("Fraction of Positives")
plt.grid(True)
plt.legend()


frac_pos, mean_pred = calibration_curve(test_true_interception, test_prob_interception, n_bins=10, strategy='quantile')
brier = brier_score_loss(test_true_interception, test_prob_interception)


plt.subplot(1, 2, 2)
plt.plot(mean_pred, frac_pos, 'o-', label="Model")
plt.plot([0, 1], [0, 1], 'k--', label="Perfect")
plt.title(f"Calibration Curve for 'Interception' Test\nBrier Score: {brier:.4f}")
plt.xlabel("Mean Predicted Prob")
plt.ylabel("Fraction of Positives")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.savefig("../outputs/images/interception_calibration_aug.png")

plt.show()

# %%
train_true_interception.mean(), train_prob_interception.mean()
# Out:
# (0.022581127560939135, 0.055787876)

# %%
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)

plt.hist(train_prob_interception)

plt.xlabel("Predicted Interception Percentage")
plt.ylabel("Frequency")
plt.title("Distribution of Train Classification Outputs")

plt.subplot(1, 2, 2)

plt.hist(test_prob_interception)

plt.xlabel("Predicted Interception Percentage")
plt.ylabel("Frequency")
plt.title("Distribution of Test Classification Outputs")
plt.savefig("../outputs/images/interception_histogram_aug.png")

plt.show()

# %% [markdown]
# ### Regression scatter plot + correlation

# %%
reg_model.eval()
with torch.no_grad():
    r_preds = reg_model(Xr_test_tensor).squeeze().numpy()

from scipy.stats import pearsonr
r_corr, _ = pearsonr(yr_test, r_preds)

plt.figure(figsize=(7, 6))
plt.scatter(yr_test, r_preds, alpha=0.5, edgecolors='k')
plt.plot([yr_test.min(), yr_test.max()], [yr_test.min(), yr_test.max()], 'r--')
plt.title(f"Predicted vs Actual Yards Gained (Test) \n(Pearson r = {r_corr:.2f})")
plt.xlabel("Actual Yards")
plt.ylabel("Predicted Yards")
plt.grid(True)
plt.savefig("../outputs/images/yards_gained_linear_coorelation_aug.png")

plt.show()

# %%
plt.hist(r_preds, bins=40)
# Out:
# (array([ 22.,  73., 146., 171., 215., 177.,  83.,  42.,  34.,  22.,  17.,
#          19.,  12.,  12.,  12.,   7.,   8.,   8.,   9.,   2.,   2.,   2.,
#           3.,   5.,   2.,   4.,   6.,   1.,   1.,   1.,   0.,   0.,   1.,
#           0.,   1.,   2.,   0.,   0.,   0.,   1.]),
#  array([ 2.25442457,  3.6914084 ,  5.12839222,  6.56537628,  8.00236034,
#          9.43934441, 10.87632751, 12.31331158, 13.75029564, 15.1872797 ,
#         16.62426376, 18.06124687, 19.49823189, 20.935215  , 22.3721981 ,
#         23.80918312, 25.24616623, 26.68315125, 28.12013435, 29.55711746,
#         30.99410248, 32.43108749, 33.8680687 , 35.30505371, 36.74203873,
#         38.17901993, 39.61600494, 41.05298996, 42.48997498, 43.92695618,
#         45.36394119, 46.80092621, 48.23790741, 49.67489243, 51.11187744,
#         52.54885864, 53.98584366, 55.42282867, 56.85981369, 58.29679489,
#         59.73377991]),
#  <BarContainer object of 40 artists>)

# %%
plt.hist(yr_test, bins=40)
# Out:
# (array([  1.,   0.,   0.,   0.,   2.,   4.,  11.,  17., 104., 102., 159.,
#         216., 100.,  84.,  91.,  38.,  33.,  46.,  23.,  13.,  21.,   9.,
#           6.,   7.,   5.,   7.,   2.,   5.,   6.,   2.,   1.,   3.,   1.,
#           2.,   1.,   0.,   0.,   0.,   0.,   1.]),
#  array([-19.  , -16.65, -14.3 , -11.95,  -9.6 ,  -7.25,  -4.9 ,  -2.55,
#          -0.2 ,   2.15,   4.5 ,   6.85,   9.2 ,  11.55,  13.9 ,  16.25,
#          18.6 ,  20.95,  23.3 ,  25.65,  28.  ,  30.35,  32.7 ,  35.05,
#          37.4 ,  39.75,  42.1 ,  44.45,  46.8 ,  49.15,  51.5 ,  53.85,
#          56.2 ,  58.55,  60.9 ,  63.25,  65.6 ,  67.95,  70.3 ,  72.65,
#          75.  ]),
#  <BarContainer object of 40 artists>)

# %%
yr_test.mean(), r_preds.mean()
# Out:
# (11.311665182546749, 10.803815)

# %%
abs(yr_test - r_preds).mean()
# Out:
# 4.808021985730845

# %%
reg_model.eval()
with torch.no_grad():
    r_preds = reg_model(Xr_train_tensor).squeeze().numpy()

from scipy.stats import pearsonr
r_corr, _ = pearsonr(yr_train, r_preds)

plt.figure(figsize=(7, 6))
plt.scatter(yr_train, r_preds, alpha=0.5, edgecolors='k')
plt.plot([yr_train.min(), yr_train.max()], [yr_train.min(), yr_train.max()], 'r--')
plt.title(f"Predicted vs Actual Yards Gained (Train) \n(Pearson r = {r_corr:.2f})")
plt.xlabel("Actual Yards")
plt.ylabel("Predicted Yards")
plt.grid(True)
plt.show()

# %%
yr_train.mean(), r_preds.mean()
# Out:
# (10.927426536064115, 10.492444)

# %%
from scipy.stats import pearsonr
completed = features[features["pass_result"] == "C"]
r_corr, _ = pearsonr(completed["yards_gained"], completed["target_x_relative"])

plt.figure(figsize=(7, 6))
plt.scatter(completed["yards_gained"], completed["target_x_relative"], alpha=0.5, edgecolors='k')
plt.plot([yr_test.min(), yr_test.max()], [yr_test.min(), yr_test.max()], 'r--')
plt.title(f"Targeted Reciever X Relative vs Actual Yards Gained\n(Pearson r = {r_corr:.2f})")
plt.xlabel("Actual Yards")
plt.ylabel("Targeted Reciever X Relative")
plt.grid(True)
plt.show()

# %% [markdown]
# # QB Analysis

# %%
from collections import defaultdict

qb_metrics = defaultdict(dict)

# Get unique QB ids
qb_ids = raw_features["player_0_nflId"].unique()

# %%
for qb_id in qb_ids:
    # Filter rows for this QB
    qb_mask = features["player_0_nflId"] == qb_id
    qb_rows = Xc_s[qb_mask]
    
    if len(qb_rows) == 0:
        continue

    # Get relevant model inputs
    X_clf_qb = Xc_s[qb_mask]
    y_true_class = y_clf_enc[qb_mask]

    qb_mask = reg_df["player_0_nflId"] == qb_id
    X_reg_qb = Xr_s[qb_mask]
    y_true_reg = y_reg[qb_mask].reset_index(drop=True)

    # Convert to tensor
    X_clf_tensor = torch.tensor(X_clf_qb, dtype=torch.float32)
    X_reg_tensor = torch.tensor(X_reg_qb, dtype=torch.float32)


    # Run through model
    with torch.no_grad():
        logits = clf_model(X_clf_tensor)
        yards_pred = reg_model(X_reg_tensor)
        probs = torch.softmax(logits, dim=1).numpy()
        class_preds = torch.argmax(logits, dim=1).numpy()
        reg_preds = yards_pred.squeeze().numpy()
    
    # === Completion Metrics ===
    actual_completion = (y_true_class == 0).mean()
    expected_completion = probs[:, 0].mean()

    # === Yards Gained ===
    actual_yards = y_true_reg.mean()
    expected_yards = reg_preds.mean()

    # === Save Basic Metrics ===
    qb_metrics[qb_id]["actual_completion"] = actual_completion
    qb_metrics[qb_id]["expected_completion"] = expected_completion
    qb_metrics[qb_id]["actual_yards"] = actual_yards
    qb_metrics[qb_id]["expected_yards"] = expected_yards
    qb_metrics[qb_id]["total_throws"] = len(X_clf_qb)
# Out:
# C:\Users\jesse\AppData\Local\Temp\ipykernel_28116\136520587.py:36: RuntimeWarning: Mean of empty slice.
#   expected_yards = reg_preds.mean()
# c:\Users\jesse\anaconda3\envs\nflenv\lib\site-packages\numpy\core\_methods.py:192: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)

# %%
for qb_id in qb_ids:
    qb_mask = features["player_0_nflId"] == qb_id
    qb_rows = Xc_s[qb_mask]
    
    if len(qb_rows) == 0:
        continue

    # === Classification rows ===
    X_clf_qb = Xc_s[qb_mask]
    y_true_class = y_clf_enc[qb_mask]

    # === Regression rows (only completions) ===
    qb_mask_reg = reg_df["player_0_nflId"] == qb_id
    X_reg_qb = Xr_s[qb_mask_reg]
    y_true_reg = y_reg[qb_mask_reg].reset_index(drop=True)

    # Convert to tensors
    X_clf_tensor = torch.tensor(X_clf_qb, dtype=torch.float32)
    X_reg_tensor = torch.tensor(X_reg_qb, dtype=torch.float32)
    if len(X_reg_tensor) < 10:
        continue

    with torch.no_grad():
        logits = clf_model(X_clf_tensor)
        yards_pred = reg_model(X_reg_tensor)

        probs = torch.softmax(logits, dim=1).numpy()
        class_preds = torch.argmax(logits, dim=1).numpy()
        reg_preds = yards_pred.squeeze().numpy()

    # === Completion metrics ===
    actual_completion = (y_true_class == 0).mean()
    expected_completion = probs[:, 0].mean()

    # === Interception metrics ===
    actual_interception = (y_true_class == 2).mean()
    expected_interception = probs[:, 2].mean()

    # === Yards gained metrics ===
    actual_yards = y_true_reg.mean() if len(y_true_reg) > 0 else 0.0
    expected_yards = reg_preds.mean() if len(reg_preds) > 0 else 0.0

    # === Save all metrics ===
    qb_metrics[qb_id]["total_throws"] = len(X_clf_qb)

    qb_metrics[qb_id]["actual_completion"] = actual_completion
    qb_metrics[qb_id]["expected_completion"] = expected_completion

    qb_metrics[qb_id]["actual_interception"] = actual_interception
    qb_metrics[qb_id]["expected_interception"] = expected_interception

    qb_metrics[qb_id]["actual_yards"] = actual_yards
    qb_metrics[qb_id]["expected_yards"] = expected_yards

# %%
X_clf_index = X_clf.index
X_reg_index = X_reg.index

Xc_s_df = pd.DataFrame(Xc_s, index=X_clf_index, columns=X_clf.columns)

Xr_s_df = pd.DataFrame(Xr_s, index=X_reg_index, columns=X_reg.columns)

# %%
receiver_range = range(6, 11)
receiver_attrs = ['x', 'x_relative', 'y', 's', 'a', 'dis', 'o', 'dir']
real_results = []
fake_results = []
targeted_indexes = []
optimal_indexes = []

for qb_id in qb_ids:
    qb_mask = features["player_0_nflId"] == qb_id
    qb_rows = Xc_s_df[qb_mask].copy()

    total_plays = 0
    optimal_target_count = 0
    efficiency_sum = 0
    optimal_sum = 0

    for _, row in qb_rows.iterrows():
        target_idx = features.loc[row.name]["target_receiver_index"]
        if not 0 <= target_idx <= 4:
            continue  # skip invalid

        base_input = Xc_s_df.loc[row.name].copy()  # original row

        candidate_values = []

        for i in range(5):
            receiver_idx = i + 6
            modified_row = base_input.copy()

            for attr in receiver_attrs:
                modified_row[f'target_{attr}'] = row[f'player_{receiver_idx}_{attr}']

            # Model prediction
            inp = torch.tensor(modified_row.values.reshape(1, -1), dtype=torch.float32)
            with torch.no_grad():
                output = clf_model(inp)
                class_probs = torch.softmax(output, dim=1)
                yp = reg_model(inp)
                candidate_values.append(yp.item() * class_probs[0, 0])
                if i == target_idx:
                    real_results.append([yp.item(), class_probs[0, 0]])
                else:
                    fake_results.append([yp.item(), class_probs[0, 0]])

        actual_value = candidate_values[target_idx].item()
        optimal_value = max(candidate_values).item()

        optimal_sum += optimal_value
        targeted_indexes.append(target_idx)
        optimal_indexes.append(np.argmax(candidate_values))

        if np.argmax(candidate_values) == target_idx:
            optimal_target_count += 1

        if optimal_value > 0:
            efficiency_sum += actual_value / optimal_value

        total_plays += 1

    if total_plays > 0:
        qb_metrics[qb_id]["decision_efficiency_ratio"] = efficiency_sum / total_plays
        qb_metrics[qb_id]["optimal_target_rate"] = optimal_target_count / total_plays
        qb_metrics[qb_id]["average_optimal"] = optimal_sum / total_plays

# %%
plt.hist(optimal_indexes)
# Out:
# (array([1727.,    0., 1956.,    0.,    0., 1582.,    0., 1495.,    0.,
#         1599.]),
#  array([0. , 0.4, 0.8, 1.2, 1.6, 2. , 2.4, 2.8, 3.2, 3.6, 4. ]),
#  <BarContainer object of 10 artists>)

# %%
# Create DataFrame from metrics
qb_results_df = pd.DataFrame.from_dict(qb_metrics, orient="index")
qb_results_df.reset_index(inplace=True)
qb_results_df.rename(columns={"index": "qb_nflId"}, inplace=True)

# Map QB display names using features
qb_id_to_name = raw_features.set_index("player_0_nflId")["player_0_displayName_x"].to_dict()
qb_results_df["qb_name"] = qb_results_df["qb_nflId"].map(qb_id_to_name)

# Add CPOE and YOE
qb_results_df["completion_over_expected"] = qb_results_df["actual_completion"] - qb_results_df["expected_completion"]
qb_results_df["yards_over_expected"] = qb_results_df["actual_yards"] - qb_results_df["expected_yards"]

# Filter QBs with at least 150 throws
qb_filtered = qb_results_df[qb_results_df["total_throws"] >= 100]

# Sort by completion over expected

# View top 10

# %%
qb_sorted = qb_filtered.sort_values("actual_interception", ascending=False)
#inlcude time to throw average. 

qb_sorted[["qb_name", "actual_completion", "expected_completion","completion_over_expected", "expected_yards", "yards_over_expected","average_optimal","optimal_target_rate", "decision_efficiency_ratio","actual_interception","expected_interception","total_throws"]]
# Out:
#               qb_name  actual_completion  expected_completion  \
# 18     Jameis Winston             0.6476               0.6227
# 39      Kenny Pickett             0.7143               0.7039
# 31          Mac Jones             0.6962               0.6896
# 28        Davis Mills             0.6498               0.6911
# 17         Josh Allen             0.6641                0.674
# 12          Matt Ryan              0.719               0.6851
# 20      Justin Fields             0.5954               0.6674
# 41        Andy Dalton             0.6954               0.6747
# 5          Jared Goff             0.6546               0.6525
# 6      Baker Mayfield             0.5782               0.6754
# 40        Zach Wilson             0.6358               0.6554
# 24     Marcus Mariota             0.6387               0.6546
# 30   Matthew Stafford             0.7026               0.6911
# 22      Lamar Jackson             0.6511               0.6502
# 3        Carson Wentz             0.6481               0.6962
# 34       Kirk Cousins                0.7               0.6792
# 15    Jacoby Brissett              0.674               0.6507
# 9          Joe Flacco             0.6304               0.6621
# 1       Aaron Rodgers             0.6747               0.6972
# 35    Jimmy Garoppolo             0.6786               0.6946
# 21        Cooper Rush             0.5878               0.6561
# 8     Patrick Mahomes             0.7036               0.6851
# 7          Derek Carr             0.6562               0.6498
# 25     Russell Wilson              0.625               0.6644
# 16         Joe Burrow             0.7147               0.6746
# 13  Mitchell Trubisky              0.625               0.6622
# 2      Justin Herbert             0.6741               0.6827
# 29     Ryan Tannehill             0.6875               0.6746
# 32       Kyler Murray             0.7059               0.6984
# 10     Tua Tagovailoa             0.7122               0.6767
# 4     Trevor Lawrence             0.6861               0.6938
# 26         Geno Smith             0.7447               0.6827
# 19       Daniel Jones             0.6923               0.6832
# 0         Jalen Hurts             0.7163               0.6834
# 14          Tom Brady             0.6731               0.6921
#
#     completion_over_expected  expected_yards  yards_over_expected  \
# 18                   0.02493            12.5              -0.6941
# 39                   0.01043           9.264              -0.9096
# 31                   0.00665           10.63              -0.1561
# 28                  -0.04133            10.5             -0.06865
# 17                 -0.009904           11.63               0.9623
# 12                    0.0339            10.1              -0.1668
# 20                    -0.072           11.18               0.2665
# 41                   0.02075           11.39              0.08215
# 5                   0.002136           10.56                1.614
# 6                   -0.09715           11.59               0.4806
# 40                  -0.01964           11.02                1.639
# 24                  -0.01583           11.31                1.379
# 30                   0.01154           10.02               0.1123
# 22                 0.0008282           10.54               0.6034
# 3                   -0.04809           10.55              0.08597
# 34                   0.02075           10.27              -0.2839
# 15                   0.02327           11.78               0.1054
# 9                   -0.03167           9.829              -0.3807
# 1                   -0.02259           9.719               0.2254
# 35                  -0.01606           10.71                2.017
# 21                   -0.0683           10.59               0.9284
# 8                    0.01845            10.8                1.151
# 7                    0.00642           10.74              -0.0564
# 25                  -0.03939           11.99               0.8858
# 16                   0.04013           10.53               0.5058
# 13                  -0.03718           11.11               -1.187
# 2                  -0.008566           9.854             -0.06694
# 29                   0.01292           11.49               0.9299
# 32                  0.007458           9.163              -0.1232
# 10                    0.0355           11.83                1.322
# 4                  -0.007705           9.687                1.031
# 26                   0.06193            10.5               0.4622
# 19                   0.00913           9.662              0.04921
# 0                    0.03288           11.17                1.154
# 14                  -0.01896           9.396               0.5958
#
#     average_optimal  optimal_target_rate  decision_efficiency_ratio  \
# 18            10.32               0.1429                      0.763
# 39            10.32               0.1688                     0.7514
# 31            10.56               0.1582                     0.7313
# 28            10.35               0.1477                     0.7363
# 17            9.962               0.1756                     0.7821
# 12            9.896               0.1679                     0.7566
# 20            10.67                0.185                     0.7398
# 41            10.24               0.1322                      0.772
# 5              10.7               0.1566                     0.7176
# 6             10.85               0.1633                      0.746
# 40            10.78               0.1921                     0.7363
# 24            10.57               0.2042                     0.7561
# 30            9.969               0.1227                     0.7371
# 22            9.899               0.1787                      0.757
# 3             10.51               0.1574                     0.7327
# 34            10.03               0.1185                     0.7196
# 15            10.81                0.163                     0.7371
# 9             9.574               0.1667                     0.7607
# 1             9.803               0.1781                     0.7527
# 35            11.72               0.1327                     0.6905
# 21            9.358               0.1284                     0.7582
# 8             9.876                0.215                     0.7786
# 7             10.75                0.168                     0.7262
# 25            11.02               0.1779                     0.7542
# 16            9.945               0.1827                     0.7606
# 13            10.16               0.1667                       0.78
# 2             10.12               0.1725                     0.7458
# 29            10.87               0.1562                     0.7359
# 32            9.867               0.1641                     0.7382
# 10            10.26               0.1951                     0.7579
# 4             10.28               0.1496                       0.74
# 26            9.992               0.1319                     0.7194
# 19             10.1               0.1744                     0.7339
# 0             10.23               0.1535                     0.7314
# 14            9.345               0.1385                     0.7535
#
#     actual_interception  expected_interception  total_throws
# 18              0.04762                0.06713           105
# 39              0.04545                  0.052           154
# 31               0.0443                0.05488           158
# 28              0.03376                0.05386           237
# 17              0.03053                 0.0577           262
# 12               0.0292                0.05306           274
# 20               0.0289                0.05821           173
# 41              0.02874                 0.0586           174
# 5               0.02811                 0.0588           249
# 6               0.02721                0.05586           147
# 40              0.02649                0.05861           151
# 24              0.02618                0.05925           191
# 30              0.02602                0.05364           269
# 22              0.02553                0.05898           235
# 3               0.02315                0.05291           216
# 34              0.02222                0.05424           270
# 15              0.02203                0.05833           227
# 9               0.02174                0.05842           138
# 1               0.02055                0.05296           292
# 35              0.02041                0.05252           196
# 21              0.02027                0.06135           148
# 8               0.01954                0.05467           307
# 7               0.01953                0.05981           256
# 25              0.01923                0.05718           208
# 16              0.01923                0.05337           312
# 13              0.01667                0.06067           120
# 2               0.01597                0.05427           313
# 29              0.01562                0.05662           128
# 32              0.01548                0.05204           323
# 10              0.01463                0.05655           205
# 4                0.0146                0.05331           274
# 26              0.01277                0.05193           235
# 19              0.01026                0.05706           195
# 0              0.009302                0.05521           215
# 14              0.00277                0.05292           361

# %%
# Round to 3 significant figures in display
pd.set_option('display.float_format', lambda x: '{:.4g}'.format(x))

# Select desired columns
df_to_print = qb_sorted[["qb_name", "completion_over_expected"	 ]].head(5)

# Print without index
print(df_to_print.to_string(index=False))
# Out:
#        qb_name  completion_over_expected
# Jameis Winston                   0.02493
#  Kenny Pickett                   0.01043
#      Mac Jones                   0.00665
#    Davis Mills                  -0.04133
#     Josh Allen                 -0.009904

# %%
qb_sorted.shape
# Out:
# (35, 14)

# %% [markdown]
# ## Create and save predictions for all plays with all frames

# %%
    
features[features["game_id"] == 2022091200]["play_id"].unique()
# Out:
# array([3574., 1465.,  109.,  286., 2093., 3491., 1344.,  565., 1320.,
#        3001., 2244., 3048., 1579., 2268., 1764.,  201., 3296., 3101.,
#        1241., 1487.,  401., 3382., 1793., 2038., 2688., 2801., 3216.,
#        2009., 3325., 1550., 2500.,   85., 2188.,  156., 1521., 3267.,
#        1028., 2522., 3747.,  786., 1004.,  346.,  664., 2750., 3125.,
#        3149., 3628., 2546., 3723.,  467.,  762., 3826., 2591., 1725.,
#        3245., 2779., 1851.,  688., 1680., 3194.,  931., 3467., 1057.,
#         264., 3596., 1217., 1409., 3404.])

# %%
features.sort_values(by="yards_gained")[["game_id", "play_id", "yards_gained"]].astype(int).head(10)
# Out:
#          game_id  play_id  yards_gained
# 1456  2022091811     4519           -61
# 8024  2022110600     2183           -39
# 4866  2022100901     2727           -19
# 7409  2022103002     2935           -19
# 2291  2022092506     3745           -15
# 2253  2022092512     1320           -15
# 765   2022091200     2546           -14
# 4891  2022100907     3783           -13
# 7136  2022103008     1425           -10
# 287   2022091100     3554           -10

# %%
features
# Out:
#       player_0_nflId  player_0_displayName_x  player_0_position  player_0_x  \
# 0          5.246e+04                     NaN                NaN        38.3
# 1          2.985e+04                     NaN                NaN       26.75
# 2          5.241e+04                     NaN                NaN       51.18
# 3          4.329e+04                     NaN                NaN       28.98
# 4          5.343e+04                     NaN                NaN       100.8
# ...              ...                     ...                ...         ...
# 8354        4.61e+04                     NaN                NaN       20.65
# 8355       4.482e+04                     NaN                NaN       58.18
# 8356       5.344e+04                     NaN                NaN       61.61
# 8357       5.241e+04                     NaN                NaN       60.85
# 8358       5.343e+04                     NaN                NaN       34.22
#
#       player_0_x_relative  player_0_y  player_0_s  player_0_a  player_0_dis  \
# 0                    -6.7       27.87        1.58        0.44          0.16
# 1                   -8.25       39.46        5.43        1.05          0.55
# 2                   -5.82        22.2        2.64        1.03          0.27
# 3                   -6.02       28.89        1.34         0.2          0.13
# 4                   -6.24       17.14        7.65        2.38          0.77
# ...                   ...         ...         ...         ...           ...
# 8354               -10.35       24.91        0.83        0.36          0.09
# 8355                -5.82       24.39        2.33        0.29          0.22
# 8356                -5.39       23.47        0.95        3.09          0.11
# 8357                -8.15       28.94        1.64        0.69          0.16
# 8358                -6.78       26.96        0.72        2.24          0.08
#
#       player_0_o  ...  end_frame  play_type  down  yards_to_go  \
# 0          179.3  ...        121          I     3           12
# 1          94.31  ...        196         IN     1           10
# 2          108.8  ...        122          C     1           10
# 3          176.9  ...         69          C     2            7
# 4          129.3  ...        104          C     2            3
# ...          ...  ...        ...        ...   ...          ...
# 8354       139.4  ...        127          C     3            8
# 8355       46.34  ...        106          C     1           10
# 8356       170.7  ...        147          C     1           10
# 8357       135.9  ...        121          C     2           15
# 8358       155.9  ...        126          I     3            4
#
#       line_of_scrimmage  yards_gained  pass_result  targeted_receiver_nflId  \
# 0                    65             0            I                5.344e+04
# 1                    75             0           IN                3.714e+04
# 2                    53            42            C                4.002e+04
# 3                    75            -1            C                4.485e+04
# 4                     3             3            C                5.273e+04
# ...                 ...           ...          ...                      ...
# 8354                 79            19            C                4.785e+04
# 8355                 46             0            C                4.001e+04
# 8356                 43             3            C                4.332e+04
# 8357                 41             6            C                5.324e+04
# 8358                 69             0            I                4.484e+04
#
#       time_to_throw  frames_from_snap
# 0                15                15
# 1                45                45
# 2                35                35
# 3                15                15
# 4                29                29
# ...             ...               ...
# 8354             41                41
# 8355             13                13
# 8356             20                20
# 8357             30                30
# 8358             18                18
#
# [8359 rows x 276 columns]

# %%
features
# Out:
#       player_0_nflId  player_0_displayName_x  player_0_position  player_0_x  \
# 0          5.246e+04                     NaN                NaN        38.3
# 1          2.985e+04                     NaN                NaN       26.75
# 2          5.241e+04                     NaN                NaN       51.18
# 3          4.329e+04                     NaN                NaN       28.98
# 4          5.343e+04                     NaN                NaN       100.8
# ...              ...                     ...                ...         ...
# 8354        4.61e+04                     NaN                NaN       20.65
# 8355       4.482e+04                     NaN                NaN       58.18
# 8356       5.344e+04                     NaN                NaN       61.61
# 8357       5.241e+04                     NaN                NaN       60.85
# 8358       5.343e+04                     NaN                NaN       34.22
#
#       player_0_x_relative  player_0_y  player_0_s  player_0_a  player_0_dis  \
# 0                    -6.7       27.87        1.58        0.44          0.16
# 1                   -8.25       39.46        5.43        1.05          0.55
# 2                   -5.82        22.2        2.64        1.03          0.27
# 3                   -6.02       28.89        1.34         0.2          0.13
# 4                   -6.24       17.14        7.65        2.38          0.77
# ...                   ...         ...         ...         ...           ...
# 8354               -10.35       24.91        0.83        0.36          0.09
# 8355                -5.82       24.39        2.33        0.29          0.22
# 8356                -5.39       23.47        0.95        3.09          0.11
# 8357                -8.15       28.94        1.64        0.69          0.16
# 8358                -6.78       26.96        0.72        2.24          0.08
#
#       player_0_o  ...  end_frame  play_type  down  yards_to_go  \
# 0          179.3  ...        121          I     3           12
# 1          94.31  ...        196         IN     1           10
# 2          108.8  ...        122          C     1           10
# 3          176.9  ...         69          C     2            7
# 4          129.3  ...        104          C     2            3
# ...          ...  ...        ...        ...   ...          ...
# 8354       139.4  ...        127          C     3            8
# 8355       46.34  ...        106          C     1           10
# 8356       170.7  ...        147          C     1           10
# 8357       135.9  ...        121          C     2           15
# 8358       155.9  ...        126          I     3            4
#
#       line_of_scrimmage  yards_gained  pass_result  targeted_receiver_nflId  \
# 0                    65             0            I                5.344e+04
# 1                    75             0           IN                3.714e+04
# 2                    53            42            C                4.002e+04
# 3                    75            -1            C                4.485e+04
# 4                     3             3            C                5.273e+04
# ...                 ...           ...          ...                      ...
# 8354                 79            19            C                4.785e+04
# 8355                 46             0            C                4.001e+04
# 8356                 43             3            C                4.332e+04
# 8357                 41             6            C                5.324e+04
# 8358                 69             0            I                4.484e+04
#
#       time_to_throw  frames_from_snap
# 0                15                15
# 1                45                45
# 2                35                35
# 3                15                15
# 4                29                29
# ...             ...               ...
# 8354             41                41
# 8355             13                13
# 8356             20                20
# 8357             30                30
# 8358             18                18
#
# [8359 rows x 276 columns]

# %%
features["yards_gained"].mean()
# Out:
# 7.391912908242613

# %%
378 / 8359 / 2
# Out:
# 0.022610360090919965
